# %% [markdown]
# # 03 Semantic Segementation

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install wget #For colab
# Out:
# Collecting wget
#   Downloading https://files.pythonhosted.org/packages/47/6a/62e288da7bcda82b935ff0c6cfe542970f04e29c756b0e147251b2fb251f/wget-3.2.zip
# Building wheels for collected packages: wget
#   Building wheel for wget (setup.py) ... done
#   Created wheel for wget: filename=wget-3.2-cp36-none-any.whl size=9682 sha256=e31b97b1dc9b9c02a96b144f5e21a08b6740a9f9db294155f85844b06a2b3bc5
#   Stored in directory: /root/.cache/pip/wheels/40/15/30/7d8f7cea2902b4db79e3fea550d7d7b85ecb27ef992b618f3f
# Successfully built wget
# Installing collected packages: wget
# Successfully installed wget-3.2

# %%
import wget, argparse, zipfile, tarfile, sys
from pathlib import Path

def simple_progress_bar(current, total, width=80):
    progress_message = "Downloading: %d%% [%d / %d] bytes" % (current / total * 100, current, total)
    sys.stdout.write("\r" + progress_message); sys.stdout.flush()

def get_and_unpack(url, location='data/'):
    Path(location).mkdir(exist_ok=True)
    filename = wget.download(url, out=location, bar=simple_progress_bar)
    zip_ref = zipfile.ZipFile(filename, 'r')
    zip_ref.extractall(path=location)
    zip_ref.close()

# %%
get_and_unpack(url='http://www.welchlabs.io/unccv/deep_learning/bbc_train.zip')
# Out:
# Downloading: 83% [75284480 / 90591239] bytes
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Downloading: 100% [90591239 / 90591239] bytes

# %% [markdown]
# - But wait, there's more!
# - Let's explore one more type of problem we can solve using a very similar architecture: **semantic segmentation**.
# - Our goal in semantic segmentation is to assign each pixel to a specific class.
# - Now is a good time to start thinking about what type of dimension we need for the output of our nueral network in order to solve this problem.

# %%
# %pylab inline
from fastai.vision import *
from pathlib import Path
import pandas as pd
import json
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /usr/local/lib/python3.6/dist-packages/IPython/core/magics/pylab.py:161: UserWarning: pylab import has clobbered these variables: ['subplots', 'array', 'copy', 'partition', '__version__', 'random', 'uniform', 'pad']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"

# %% [markdown]
# ### 1. Data

# %%
path=Path('/content/drive/MyDrive/bbc_train/bbc_train')

# %%
path.ls()
# Out:
# [PosixPath('/content/drive/MyDrive/bbc_train/bbc_train/bboxes.json'),
#  PosixPath('/content/drive/MyDrive/bbc_train/bbc_train/classification_labels.csv'),
#  PosixPath('/content/drive/MyDrive/bbc_train/bbc_train/.DS_Store'),
#  PosixPath('/content/drive/MyDrive/bbc_train/bbc_train/images'),
#  PosixPath('/content/drive/MyDrive/bbc_train/bbc_train/masks'),
#  PosixPath('/content/drive/MyDrive/bbc_train/bbc_train/models')]

# %%
fnames = get_image_files(path/'images')
fnames[:3]
# Out:
# [PosixPath('/content/drive/MyDrive/bbc_train/bbc_train/images/P2050895.jpg'),
#  PosixPath('/content/drive/MyDrive/bbc_train/bbc_train/images/P2050261.jpg'),
#  PosixPath('/content/drive/MyDrive/bbc_train/bbc_train/images/P2050922.jpg')]

# %%
lbl_names = get_image_files(path/'masks')
lbl_names[:3]
# Out:
# [PosixPath('/content/drive/MyDrive/bbc_train/bbc_train/masks/P2050936.png'),
#  PosixPath('/content/drive/MyDrive/bbc_train/bbc_train/masks/P2050261.png'),
#  PosixPath('/content/drive/MyDrive/bbc_train/bbc_train/masks/P2050329.png')]

# %%
img_f = fnames[0]
img = open_image(img_f)
img.show(figsize=(5,5))

# %%
def get_y_fn(x): return path/'masks'/(x.stem + '.png')
classes = array(['background', 'brick', 'ball', 'cylinder'])

# %%
mask = open_mask(get_y_fn(img_f))
mask.show(figsize=(5,5), alpha=1)

# %%
unique(mask.data)
# Out:
# array([0, 2])

# %%
src = (SegmentationItemList.from_folder(path/'images')
       .split_by_rand_pct(0.2)
       .label_from_func(get_y_fn, classes=classes))

# %%
data = (src.transform(get_transforms(), tfm_y=True, size=(256,256))
        .databunch(bs=16)
        .normalize(imagenet_stats))

# %%
data
# Out:
# ImageDataBunch;
#
# Train: LabelList (754 items)
# x: SegmentationItemList
# Image (3, 256, 256),Image (3, 256, 256),Image (3, 256, 256),Image (3, 256, 256),Image (3, 256, 256)
# y: SegmentationLabelList
# ImageSegment (1, 256, 256),ImageSegment (1, 256, 256),ImageSegment (1, 256, 256),ImageSegment (1, 256, 256),ImageSegment (1, 256, 256)
# Path: /content/drive/MyDrive/bbc_train/bbc_train/images;
#
# Valid: LabelList (188 items)
# x: SegmentationItemList
# Image (3, 256, 256),Image (3, 256, 256),Image (3, 256, 256),Image (3, 256, 256),Image (3, 256, 256)
# y: SegmentationLabelList
# ImageSegment (1, 256, 256),ImageSegment (1, 256, 256),ImageSegment (1, 256, 256),ImageSegment (1, 256, 256),ImageSegment (1, 256, 256)
# Path: /content/drive/MyDrive/bbc_train/bbc_train/images;
#
# Test: None

# %%
data.show_batch(3, figsize=(6,6))

# %% [markdown]
# ### 2. Model

# %% [markdown]
# - Now, as you may have guessed we need to implement another custom head.
# - However, this time we need a slightly more complicated architecture for this portion of our network.
# - The challenge here is that we need to **upsample**, or make our tensors larger as they pass through the network.
# - We can achieve this using a special operation called a **transposed convoulation** - we'll dig more into the details of this operation later.
# - The thing to know for knwo is that transposed convulutional layers in our neural network allow us to learn an "upsampling" or mapping form smaller to larger tensors.

# %%
def conv_trans(ni, nf, ks = 4, stride = 2, padding = 1):
    return nn.Sequential(
        nn.ConvTranspose2d(ni, nf, kernel_size=ks, bias=False, stride=stride, padding = padding), 
        nn.ReLU(inplace = True), 
        nn.BatchNorm2d(nf))

# %%
custom_head=nn.Sequential(conv_trans(512, 256), 
                          conv_trans(256, 128),
                          conv_trans(128, 64),
                          conv_trans(64, 32), 
                          nn.ConvTranspose2d(32, 4, kernel_size=4, bias=False, stride=2, padding = 1))

# %% [markdown]
# - We need to intorduce a slightly specialized performance measure here, the accuracy evaluate pixel by pixel (like we're solving a classification problem for each pixel!

# %%
def pixel_accuracy(yhat, y):
    y_=y.squeeze(dim=1)
    yhat_=yhat.argmax(dim=1)
    return (y_==yhat_).sum().float()/y.numel()

# %%
learn=cnn_learner(data, models.resnet34, custom_head=custom_head, metrics=pixel_accuracy)

# %%
learn.freeze()

# %%
learn.lr_find()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='2' class='' max='3' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       66.67% [2/3 00:37<00:18]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>pixel_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.312728</td>
#       <td>#na#</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>4.694224</td>
#       <td>#na#</td>
#       <td>00:18</td>
#     </tr>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='47' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/47 00:00<00:00]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot()

# %%
lr=1e-2
learn.fit_one_cycle(4, slice(lr/10, lr))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>pixel_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.879186</td>
#       <td>0.221693</td>
#       <td>0.951145</td>
#       <td>00:22</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.358711</td>
#       <td>0.101362</td>
#       <td>0.967033</td>
#       <td>00:22</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.188120</td>
#       <td>0.080801</td>
#       <td>0.972456</td>
#       <td>00:22</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.118430</td>
#       <td>0.068836</td>
#       <td>0.977596</td>
#       <td>00:22</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.unfreeze()

# %%
learn.lr_find()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='1' class='' max='3' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       33.33% [1/3 00:20<00:40]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>pixel_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.069649</td>
#       <td>#na#</td>
#       <td>00:20</td>
#     </tr>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='35' class='' max='47' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       74.47% [35/47 00:14<00:05 0.2691]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot()

# %%
lr=1e-4
learn.fit_one_cycle(10, slice(lr/10, lr))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>pixel_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.070446</td>
#       <td>0.063498</td>
#       <td>0.979320</td>
#       <td>00:23</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.066153</td>
#       <td>0.058230</td>
#       <td>0.980804</td>
#       <td>00:23</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.059201</td>
#       <td>0.048077</td>
#       <td>0.984214</td>
#       <td>00:23</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.053389</td>
#       <td>0.042814</td>
#       <td>0.985959</td>
#       <td>00:23</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.048305</td>
#       <td>0.037611</td>
#       <td>0.987698</td>
#       <td>00:22</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.043793</td>
#       <td>0.035449</td>
#       <td>0.988385</td>
#       <td>00:23</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.040746</td>
#       <td>0.033066</td>
#       <td>0.989055</td>
#       <td>00:23</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.037399</td>
#       <td>0.032087</td>
#       <td>0.989095</td>
#       <td>00:23</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.035929</td>
#       <td>0.031547</td>
#       <td>0.989377</td>
#       <td>00:23</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.036598</td>
#       <td>0.031905</td>
#       <td>0.989498</td>
#       <td>00:23</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('basic-segmentation')

# %% [markdown]
# ### 3. Results

# %%
def blend_image_mask(im, mask, alpha=0.7):
    im_mask=np.zeros((im.shape[1], im.shape[2], 3), dtype='float32')
    for j in range(3): im_mask[:,:,j]=im.mean(axis=0)
    for j in range(1, 4):
        im_mask[mask==j] = alpha*im_mask[mask==j] + (1-alpha)*np.array([float(i==(j-1)) for i in range(3)])
    return im_mask

# %%
def make_legend():
    custom_lines = [Line2D([0], [0], color='r', lw=2, alpha=0.5),
                    Line2D([0], [0], color='g', lw=2, alpha=0.5),
                    Line2D([0], [0], color='b', lw=2, alpha=0.5)]

    legend(custom_lines, ['Brick', 'Ball', 'Cylinder'])

# %%
denorm=learn.data.denorm

# %%
with torch.no_grad():
    x,y = next(iter(learn.data.valid_dl))
    yhat = to_np(learn.model(x))
    x=denorm(x)

# %%
x.shape, y.shape, yhat.shape
# Out:
# (torch.Size([16, 3, 256, 256]),
#  torch.Size([16, 1, 256, 256]),
#  (16, 4, 256, 256))

# %%
yhat=yhat.argmax(1)

# %%
fig=figure(0, (20, 10))

for i in range(8):
    fig.add_subplot(2,4,i+1)
    im_mask=blend_image_mask(to_np(x[i]), yhat[i])
    imshow(im_mask); axis('off'); make_legend()

# %% [markdown]
# ## Save Model Weights

# %%
learn.export('/content/drive/MyDrive/bbc_train/bbc-semantic-segmentation.pkl')
